# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('Telecom_Sampled.csv')

# %%
def permis(series):
    return (round((100 * (data[series].isna().sum()/len(data))), 2))

# %%
for col in data.columns:
    print(col, '',permis(col))
# Out:
# Unnamed: 0  0.0
# mou_Mean  0.22
# totmrc_Mean  0.22
# rev_Range  0.22
# mou_Range  0.22
# change_mou  0.61
# drop_blk_Mean  0.0
# drop_vce_Range  0.0
# owylis_vce_Range  0.0
# mou_opkv_Range  0.0
# months  0.0
# totcalls  0.0
# income  25.25
# eqpdays  0.0
# custcare_Mean  0.0
# callwait_Mean  0.0
# iwylis_vce_Mean  0.0
# callwait_Range  0.0
# ccrndmou_Range  0.0
# adjqty  0.0
# ovrrev_Mean  0.22
# rev_Mean  0.22
# ovrmou_Mean  0.22
# comp_vce_Mean  0.0
# plcd_vce_Mean  0.0
# avg3mou  0.0
# avgmou  0.0
# avg3qty  0.0
# avgqty  0.0
# avg6mou  3.07
# avg6qty  3.07
# crclscod  0.0
# asl_flag  0.0
# prizm_social_one  7.09
# area  0.02
# refurb_new  0.0
# hnd_webcap  8.98
# marital  1.76
# ethnic  1.76
# age1  1.76
# age2  1.76
# models  0.0
# hnd_price  0.96
# actvsubs  0.0
# uniqsubs  0.0
# forgntvl  1.76
# dwlltype  31.6
# dwllsize  38.05
# mailordr  64.15
# occu1  73.49
# opk_dat_Mean  0.0
# mtrcycle  1.76
# numbcars  48.87
# retdays  96.73
# truck  1.76
# wrkwoman  87.66
# ...

# %%
data = data.dropna(thresh=18560, axis=1)

# %%
fig, axes = plt.subplots(1,2, sharex=True, figsize=(16,6), sharey=True)
# plt.xlim(0,10)
# plt.ylim(0,0.005)
sns.despine(left=True)
sns.distplot(data.mou_Mean[data.churn == 0], color='r', ax=axes[0], bins=50).set_title('0')
sns.distplot(data.mou_Mean[data.churn == 1], color='g', ax=axes[1], bins=50).set_title('1')
plt.suptitle("Density graph - MOU_Mean Vs Churn", size=25)
# Out:
# /home/ritesh/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/ritesh/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# /home/ritesh/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /home/ritesh/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# Text(0.5, 0.98, 'Density graph - MOU_Mean Vs Churn')

# %%
fig, axes = plt.subplots(1,2, sharex=True, figsize=(16,6), sharey=True)
plt.xlim(0,400)
# plt.ylim(0,0.005)
sns.despine(left=True)
sns.distplot(data.rev_Range[data.churn == 0], color='r', ax=axes[0], bins=50).set_title('0')
sns.distplot(data.rev_Range[data.churn == 1], color='g', ax=axes[1], bins=50).set_title('1')
plt.suptitle("Density graph - rev_Range Vs Churn", size=25)
# Out:
# Text(0.5, 0.98, 'Density graph - rev_Range Vs Churn')

# %%
fig, axes = plt.subplots(1,2, sharex=True, figsize=(16,6), sharey=True)
plt.xlim(-10,100)
# plt.ylim(0,0.005)
sns.despine(left=True)
sns.distplot(data.totmrc_Mean[data.churn == 0], color='r', ax=axes[0], bins=100).set_title('0')
sns.distplot(data.totmrc_Mean[data.churn == 1], color='g', ax=axes[1], bins=100).set_title('1')
plt.suptitle("Density graph - totmrc_Mean Vs Churn", size=25)
# Out:
# Text(0.5, 0.98, 'Density graph - totmrc_Mean Vs Churn')

# %%
fig, axes = plt.subplots(1,2, sharex=True, figsize=(16,6), sharey=True)
# plt.xlim(-10,100)
# plt.ylim(0,0.005)
sns.despine(left=True)
sns.distplot(data.drop_blk_Mean[data.churn == 0], color='r', ax=axes[0], bins=100).set_title('0')
sns.distplot(data.drop_blk_Mean[data.churn == 1], color='g', ax=axes[1], bins=100).set_title('1')
plt.suptitle("Density graph - drop_blk_mean Vs Churn", size=25)
# Out:
# Text(0.5, 0.98, 'Density graph - drop_blk_mean Vs Churn')

# %%
fig, axes = plt.subplots(1,2, sharex=True, figsize=(16,6), sharey=True)
# plt.xlim(-10,50)
# plt.ylim(0,0.005)
sns.despine(left=True)
sns.distplot(data.drop_vce_Range[data.churn == 0], color='r', ax=axes[0], bins=100).set_title('0')
sns.distplot(data.drop_vce_Range[data.churn == 1], color='g', ax=axes[1], bins=100).set_title('1')
plt.suptitle("Density graph - drop_vce_Range Vs Churn", size=25)
# Out:
# Text(0.5, 0.98, 'Density graph - drop_vce_Range Vs Churn')

# %%
fig, axes = plt.subplots(1,2, sharex=True, figsize=(16,6), sharey=True)
# plt.xlim(-10,100)
# plt.ylim(0,0.005)
sns.despine(left=True)
sns.distplot(data.totcalls[data.churn == 0], color='r', ax=axes[0], bins=100).set_title('0')
sns.distplot(data.totcalls[data.churn == 1], color='g', ax=axes[1], bins=100).set_title('1')
plt.suptitle("Density graph - totcalls Vs Churn", size=25)
# Out:
# Text(0.5, 0.98, 'Density graph - totcalls Vs Churn')

# %%
fig, axes = plt.subplots(1,2, sharex=True, figsize=(16,6), sharey=True)
# plt.xlim(-10,100)
# plt.ylim(0,0.005)
sns.despine(left=True)
sns.distplot(data.owylis_vce_Range[data.churn == 0], color='r', ax=axes[0], bins=100).set_title('0')
sns.distplot(data.owylis_vce_Range[data.churn == 1], color='g', ax=axes[1], bins=100).set_title('1')
plt.suptitle("Density graph - owylis_vce_Range Vs Churn", size=25)
# Out:
# Text(0.5, 0.98, 'Density graph - owylis_vce_Range Vs Churn')

# %%
fig, axes = plt.subplots(1,2, sharex=True, figsize=(16,6), sharey=True)
# plt.xlim(-10,100)
# plt.ylim(0,0.005)
sns.despine(left=True)
sns.distplot(data.callwait_Mean[data.churn == 0], color='r', ax=axes[0], bins=100).set_title('0')
sns.distplot(data.callwait_Mean[data.churn == 1], color='g', ax=axes[1], bins=100).set_title('1')
plt.suptitle("Density graph - callwait_Mean Vs Churn", size=25)
# Out:
# Text(0.5, 0.98, 'Density graph - callwait_Mean Vs Churn')

# %%
corr = data.corr()
sns.heatmap(corr, cmap='plasma')

# %%
data.head()
# Out:
#    Unnamed: 0  mou_Mean  totmrc_Mean  rev_Range  mou_Range  change_mou  \
# 0       47170    190.25      63.9400      26.00       43.0      -11.25
# 1       39908    443.00      39.9900       5.10      199.0      -78.00
# 2       21017    400.50      44.9900      13.88      172.0      -67.50
# 3       23171     53.50      34.6675      18.56       78.0       12.50
# 4       21979     37.00      21.0425      35.79       74.0      -33.00
#
#    drop_blk_Mean  drop_vce_Range  owylis_vce_Range  mou_opkv_Range  ...  \
# 0       4.666667               8                20           28.44  ...
# 1       4.333333               5                33           72.46  ...
# 2       2.000000               1                 7           93.60  ...
# 3       1.333333               2                 0            4.70  ...
# 4       5.666667               1                 4           36.60  ...
#
#    datovr_Range  drop_dat_Mean  drop_vce_Mean  adjmou   totrev   adjrev  \
# ...

# %%
data.drop(['plcd_vce_Mean', 'avg3mou', 'avgmou', 'avg3qty', 'avgqty', 'avg6mou', 'avg6qty'], axis = 1, inplace=True)

# %%
data.drop('hnd_webcap', axis=1, inplace=True)

# %%
pd.options.display.max_rows = None
data.isnull().sum()
# Out:
# Unnamed: 0             0
# mou_Mean              58
# totmrc_Mean           58
# rev_Range             58
# mou_Range             58
# change_mou           161
# drop_blk_Mean          0
# drop_vce_Range         0
# owylis_vce_Range       0
# mou_opkv_Range         0
# months                 0
# totcalls               0
# income              6697
# eqpdays                0
# custcare_Mean          0
# callwait_Mean          0
# iwylis_vce_Mean        0
# callwait_Range         0
# ccrndmou_Range         0
# adjqty                 0
# ovrrev_Mean           58
# rev_Mean              58
# ovrmou_Mean           58
# comp_vce_Mean          0
# crclscod               0
# asl_flag               0
# prizm_social_one    1881
# area                   5
# refurb_new             0
# marital              468
# ethnic               468
# age1                 468
# age2                 468
# models                 0
# hnd_price            254
# actvsubs               0
# uniqsubs               0
# ...

# %%
#####
data.fillna(method='bfill', inplace=True)
data.fillna(method='ffill', inplace=True)

# %%
def labEn(df,col):
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

# %%
listcol = ['crclscod', 'asl_flag', 'prizm_social_one', 'area', 'refurb_new', 'marital', 'ethnic', 'car_buy', 'csa']	
for col in listcol:
    labEn(data, col)

# %%
X = data.drop('churn', axis = 1).values
y = data.churn.values

# %%
#Logistic Regression Model Fitting
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
Xtrain , Xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.2,random_state=56)
logreg = LogisticRegression()
logreg.fit(Xtrain, ytrain)
# Out:
# /home/ritesh/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#Predicting the test set results and calculating the accuracy
y_pred = logreg.predict(Xtest)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(Xtest, ytest)))
# Out:
# Accuracy of logistic regression classifier on test set: 1.00

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(ytest, y_pred)
print(confusion_matrix)
# Out:
# [[4034    0]
#  [   2 1268]]

# %%
#Compute precision, recall, F-measure and support
from sklearn.metrics import classification_report
print(classification_report(ytest, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4034
#            1       1.00      1.00      1.00      1270
#
#     accuracy                           1.00      5304
#    macro avg       1.00      1.00      1.00      5304
# weighted avg       1.00      1.00      1.00      5304

# %%
#ROC Curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(ytest, logreg.predict(Xtest))
fpr, tpr, thresholds = roc_curve(ytest, logreg.predict_proba(Xtest)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
#Random_forest
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(Xtrain,ytrain)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
predictions= dtree.predict(Xtest)
predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
Xtest
# Out:
# array([[5.58160000e+04, 1.30500000e+02, 5.49900000e+01, ...,
#         1.08231600e+06, 2.66666667e+00, 2.66666667e+00],
#        [3.47290000e+04, 5.22000000e+02, 8.49775000e+01, ...,
#         1.03774000e+06, 0.00000000e+00, 0.00000000e+00],
#        [4.36240000e+04, 2.24000000e+02, 6.99900000e+01, ...,
#         1.05668700e+06, 3.33333333e-01, 3.33333333e-01],
#        ...,
#        [2.64590000e+04, 6.42000000e+02, 2.49900000e+01, ...,
#         1.02139300e+06, 5.00000000e+00, 5.00000000e+00],
#        [2.09990000e+04, 3.33250000e+02, 3.99900000e+01, ...,
#         1.01010700e+06, 0.00000000e+00, 0.00000000e+00],
#        [1.66380000e+04, 3.89500000e+02, 3.00000000e+01, ...,
#         1.00152700e+06, 0.00000000e+00, 0.00000000e+00]])

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(ytest,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4034
#            1       1.00      1.00      1.00      1270
#
#     accuracy                           1.00      5304
#    macro avg       1.00      1.00      1.00      5304
# weighted avg       1.00      1.00      1.00      5304

# %%
print(confusion_matrix(ytest,predictions))
# Out:
# [[4034    0]
#  [   0 1270]]

# %%
from sklearn.ensemble import RandomForestClassifier
rfc= RandomForestClassifier(n_estimators=100)
rfc.fit(Xtrain,ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc_pred = rfc.predict(Xtest)

# %%
print(confusion_matrix(ytest,rfc_pred))
# Out:
# [[4034    0]
#  [   0 1270]]

# %%
print(classification_report(ytest,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4034
#            1       1.00      1.00      1.00      1270
#
#     accuracy                           1.00      5304
#    macro avg       1.00      1.00      1.00      5304
# weighted avg       1.00      1.00      1.00      5304

# %%
from sklearn.metrics import roc_auc_score

# Calculate roc auc
roc_value = roc_auc_score(ytest, rfc_pred)
roc_value
# Out:
# 1.0

# %%
#XGBoost
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# %%
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)

# %%
xg_reg.fit(Xtrain,ytrain)

preds = xg_reg.predict(Xtest)
# Out:
# [20:43:32] WARNING: /workspace/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.

# %%
rmse = np.sqrt(mean_squared_error(ytest, preds))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 0.321575

# %%
params = {"objective":"reg:linear",'colsample_bytree': 0.3,'learning_rate': 0.1,
                'max_depth': 5, 'alpha': 10}

cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=3,
                    num_boost_round=50,early_stopping_rounds=10,metrics="rmse", as_pandas=True, seed=123)
# Out:
# [20:43:33] WARNING: /workspace/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [20:43:33] WARNING: /workspace/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [20:43:33] WARNING: /workspace/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.

# %%
cv_results.head()
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.486420        0.000074        0.486580       0.000120
# 1         0.462230        0.017209        0.462551       0.017377
# 2         0.441273        0.033255        0.441813       0.033573
# 3         0.419974        0.028839        0.420694       0.029537
# 4         0.399653        0.016046        0.400383       0.016344

# %%
print((cv_results["test-rmse-mean"]).tail(1))
# Out:
# 49    0.084247
# Name: test-rmse-mean, dtype: float64

# %%
xg_reg = xgb.train(params=params, dtrain=data_dmatrix, num_boost_round=10)
# Out:
# [20:43:36] WARNING: /workspace/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.

# %%
import matplotlib.pyplot as plt

# %%
xgb.plot_importance(xg_reg)
plt.rcParams['figure.figsize'] = [5, 5]
plt.show()
