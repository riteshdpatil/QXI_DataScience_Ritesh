# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Telecom_Sampled.csv')

# %%
list = pd.read_csv('Telecom_Sampled.csv')

# %%
df.shape
# Out:
# (26518, 82)

# %%
df.churn = df.churn.astype('category')

# %%
print(type('df.churn'))
# Out:
# <class 'str'>

# %%
df.churn
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 26513    0
# 26514    1
# 26515    0
# 26516    0
# 26517    0
# Name: churn, Length: 26518, dtype: category
# Categories (2, int64): [0, 1]

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isna().sum()
# Out:
# Unnamed: 0        0
# mou_Mean         58
# totmrc_Mean      58
# rev_Range        58
# mou_Range        58
#                  ..
# adjrev            0
# avgrev            0
# Customer_ID       0
# comp_dat_Mean     0
# plcd_dat_Mean     0
# Length: 82, dtype: int64

# %%
sr = df.sum(axis=1)
sc = df.sum(axis=0)

# %%
Percentage_missing=round(sc(df.isna(df[,sr(df)[sc(df.isna(df))>0]]))/sr(df)*100,2)
# Out:
#   File "<ipython-input-50-058afe89dfa8>", line 1
#     Percentage_missing=round(sc(df.isna(df[,sr(df)[sc(df.isna(df))>0]]))/sr(df)*100,2)
#                                            ^
# SyntaxError: invalid syntax

# %%
#Percentage_missing=round(colSums(is.na(mydata[,colnames(mydata)[colSums(is.na(mydata))>0]]))/nrow(mydata)*100,2)

# %%
def missing(df):
    print (round((df.isnull().sum() * 100/ len(df)),2).sort_values(ascending=False))

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
Percentage_missing=round(df.isnull().mean()*100,2)

# %%
df.isnull().any()
# Out:
# Unnamed: 0       False
# mou_Mean          True
# totmrc_Mean       True
# rev_Range         True
# mou_Range         True
#                  ...
# adjrev           False
# avgrev           False
# Customer_ID      False
# comp_dat_Mean    False
# plcd_dat_Mean    False
# Length: 82, dtype: bool

# %%
df = df.drop(df[df.columns >= 0.3].index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-d33976ce0b7a> in <module>
# ----> 1 df = df.drop(df[df.columns >= 0.3].index)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in cmp_method(self, other)
#     105             # don't pass MultiIndex
#     106             with np.errstate(all="ignore"):
# --> 107                 result = ops._comp_method_OBJECT_ARRAY(op, self.values, other)
#     108
#     109         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1067         result = libops.vec_compare(x, y, op)
#    1068     else:
# -> 1069         result = libops.scalar_compare(x, y, op)
#    1070     return result
#    1071
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'float'

# %%
#Percentage_missing=round(colSums(is.na(mydata[,colnames(mydata)[colSums(is.na(mydata))>0]]))/nrow(mydata)*100,2)
#data.frame(MissingProportion=sort(Percentage_missing, decreasing = TRUE))
pm = round(df.fillna()
           Variables_with_High_NAs=colnames(mydata)[colSums(is.na(mydata))/nrow(mydata)>0.3]
Variables_with_High_NAs
# Out:
#        Unnamed: 0  mou_Mean  totmrc_Mean  rev_Range  mou_Range  change_mou  \
# 0           False     False        False      False      False       False
# 1           False     False        False      False      False       False
# 2           False     False        False      False      False       False
# 3           False     False        False      False      False       False
# 4           False     False        False      False      False       False
# ...           ...       ...          ...        ...        ...         ...
# 26513       False     False        False      False      False       False
# 26514       False     False        False      False      False       False
# 26515       False     False        False      False      False       False
# 26516       False     False        False      False      False       False
# 26517       False     False        False      False      False       False
#
#        drop_blk_Mean  drop_vce_Range  owylis_vce_Range  mou_opkv_Range  ...  \
# 0              False           False             False           False  ...
# 1              False           False             False           False  ...
# 2              False           False             False           False  ...
# 3              False           False             False           False  ...
# 4              False           False             False           False  ...
# ...              ...             ...               ...             ...  ...
# 26513          False           False             False           False  ...
# 26514          False           False             False           False  ...
# 26515          False           False             False           False  ...
# 26516          False           False             False           False  ...
# 26517          False           False             False           False  ...
#
#        div_type  drop_dat_Mean  drop_vce_Mean  adjmou  totrev  adjrev  avgrev  \
# 0          True          False          False   False   False   False   False
# 1          True          False          False   False   False   False   False
# 2          True          False          False   False   False   False   False
# 3         False          False          False   False   False   False   False
# 4          True          False          False   False   False   False   False
# ...         ...            ...            ...     ...     ...     ...     ...
# 26513      True          False          False   False   False   False   False
# 26514      True          False          False   False   False   False   False
# 26515      True          False          False   False   False   False   False
# 26516      True          False          False   False   False   False   False
# 26517     False          False          False   False   False   False   False
#
#        Customer_ID  comp_dat_Mean  plcd_dat_Mean
# 0            False          False          False
# 1            False          False          False
# 2            False          False          False
# 3            False          False          False
# 4            False          False          False
# ...            ...            ...            ...
# 26513        False          False          False
# 26514        False          False          False
# 26515        False          False          False
# 26516        False          False          False
# 26517        False          False          False
#
# [26518 rows x 82 columns]

# %%
Percentage_missing=round(df.isnull().mean()*100,2) 
#df.sort_values('Percentage_missing', inplace=True)

# %%
#Percentage_missing=round(colSums(is.na(mydata[,colnames(mydata)[colSums(is.na(mydata))>0]]))/nrow(mydata)*100,2)
#data.frame(MissingProportion=sort(Percentage_missing, decreasing = TRUE))
pm = round(colsum(isn(df[:,colnames(df)[colsum(isna(df))>0]]))/nrow(df)*100,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-6de455e86efc> in <module>
#       1 #Percentage_missing=round(colSums(is.na(mydata[,colnames(mydata)[colSums(is.na(mydata))>0]]))/nrow(mydata)*100,2)
#       2 #data.frame(MissingProportion=sort(Percentage_missing, decreasing = TRUE))
# ----> 3 pm = round(colsum(isn(df[:,colnames(df)[colsum(isna(df))>0]]))/nrow(df)*100,2)
#
# NameError: name 'colsum' is not defined

# %%
df.loc[df.churn=='No','churn'] = 0 
df.loc[df.churn=='Yes','churn'] = 1
# Out:
# /home/ritesh/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
df
# Out:
#        Unnamed: 0  mou_Mean  totmrc_Mean  rev_Range  mou_Range  change_mou  \
# 0           47170    190.25      63.9400      26.00       43.0      -11.25
# 1           39908    443.00      39.9900       5.10      199.0      -78.00
# 2           21017    400.50      44.9900      13.88      172.0      -67.50
# 3           23171     53.50      34.6675      18.56       78.0       12.50
# 4           21979     37.00      21.0425      35.79       74.0      -33.00
# ...           ...       ...          ...        ...        ...         ...
# 26513       39980   1406.25     149.9900      48.01      212.0      110.75
# 26514        7282    233.75      42.4900       0.00       95.0       55.25
# 26515       57437     71.75      29.9900       0.99       65.0       33.25
# 26516       40826    805.00      49.9900      32.63      457.0      -39.00
# 26517       26671   1008.25      75.0000      82.66      749.0      388.75
#
#        drop_blk_Mean  drop_vce_Range  owylis_vce_Range  mou_opkv_Range  ...  \
# 0           4.666667               8                20           28.44  ...
# 1           4.333333               5                33           72.46  ...
# 2           2.000000               1                 7           93.60  ...
# 3           1.333333               2                 0            4.70  ...
# 4           5.666667               1                 4           36.60  ...
# ...              ...             ...               ...             ...  ...
# 26513      16.666667               7                25           61.55  ...
# 26514       1.666667               2                14           21.15  ...
# 26515       0.000000               0                 0           30.71  ...
# 26516      14.666667               7                25           65.89  ...
# 26517       6.333333               4                 5          252.78  ...
#
#        div_type  drop_dat_Mean  drop_vce_Mean   adjmou   totrev   adjrev  \
# 0           NaN            0.0       3.666667   2376.0   519.07   489.08
# 1           NaN            0.0       3.000000   5565.0   598.53   538.55
# 2           NaN            0.0       0.333333   7866.0  1616.71  1586.36
# 3           LDD            0.0       0.666667   5844.0  1682.44  1647.63
# 4           NaN            0.0       1.333333   1573.0   967.59   916.61
# ...         ...            ...            ...      ...      ...      ...
# 26513       NaN            0.0       9.333333  17607.0  2265.43  2190.43
# 26514       NaN            0.0       1.000000   6236.0   981.41   897.85
# 26515       NaN            0.0       0.000000    806.0   330.62   288.27
# 26516       NaN            0.0      14.333333   9993.0  1202.81  1076.56
# 26517       LDD            0.0       4.666667   8536.0  1071.28   959.03
#
#        avgrev  Customer_ID  comp_dat_Mean  plcd_dat_Mean
# 0       37.62      1064525       0.000000       0.000000
# 1       44.88      1048538       0.333333       0.333333
# 2       58.75      1010139       0.000000       0.333333
# 3       68.65      1014496       0.000000       0.000000
# 4       29.57      1012053       0.000000       0.000000
# ...       ...          ...            ...            ...
# 26513  182.54      1048705       0.000000       0.000000
# 26514   44.89      1026617       0.000000       0.000000
# 26515   32.03      1085271       0.000000       0.000000
# 26516   71.77      1050542       0.000000       0.000000
# 26517   79.92      1021809       0.000000       0.000000
#
# [26518 rows x 82 columns]

# %%
#Percentage_missing=round(colSums(np.na(df[colnames(df)[colSums(np.na(df))>0]]))/nrow(df)*100,2)
#data.frame(MissingProportion=sort(Percentage_missing, decreasing = TRUE))

# %%
df.sort_values('Percentage_missing', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-a91958f51ddc> in <module>
#       1 Percentage_missing=round(df.isnull().mean()*100,2)
# ----> 2 df.sort_values('Percentage_missing', inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    5006
#    5007             by = by[0]
# -> 5008             k = self._get_label_or_level_values(by, axis=axis)
#    5009
#    5010             if isinstance(ascending, (tuple, list)):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 'Percentage_missing'

# %%
df
# Out:
#        Unnamed: 0  mou_Mean  totmrc_Mean  rev_Range  mou_Range  change_mou  \
# 0           47170    190.25      63.9400      26.00       43.0      -11.25
# 1           39908    443.00      39.9900       5.10      199.0      -78.00
# 2           21017    400.50      44.9900      13.88      172.0      -67.50
# 3           23171     53.50      34.6675      18.56       78.0       12.50
# 4           21979     37.00      21.0425      35.79       74.0      -33.00
# ...           ...       ...          ...        ...        ...         ...
# 26513       39980   1406.25     149.9900      48.01      212.0      110.75
# 26514        7282    233.75      42.4900       0.00       95.0       55.25
# 26515       57437     71.75      29.9900       0.99       65.0       33.25
# 26516       40826    805.00      49.9900      32.63      457.0      -39.00
# 26517       26671   1008.25      75.0000      82.66      749.0      388.75
#
#        drop_blk_Mean  drop_vce_Range  owylis_vce_Range  mou_opkv_Range  ...  \
# 0           4.666667               8                20           28.44  ...
# 1           4.333333               5                33           72.46  ...
# 2           2.000000               1                 7           93.60  ...
# 3           1.333333               2                 0            4.70  ...
# 4           5.666667               1                 4           36.60  ...
# ...              ...             ...               ...             ...  ...
# 26513      16.666667               7                25           61.55  ...
# 26514       1.666667               2                14           21.15  ...
# 26515       0.000000               0                 0           30.71  ...
# 26516      14.666667               7                25           65.89  ...
# 26517       6.333333               4                 5          252.78  ...
#
#        div_type  drop_dat_Mean  drop_vce_Mean   adjmou   totrev   adjrev  \
# 0           NaN            0.0       3.666667   2376.0   519.07   489.08
# 1           NaN            0.0       3.000000   5565.0   598.53   538.55
# 2           NaN            0.0       0.333333   7866.0  1616.71  1586.36
# 3           LDD            0.0       0.666667   5844.0  1682.44  1647.63
# 4           NaN            0.0       1.333333   1573.0   967.59   916.61
# ...         ...            ...            ...      ...      ...      ...
# 26513       NaN            0.0       9.333333  17607.0  2265.43  2190.43
# 26514       NaN            0.0       1.000000   6236.0   981.41   897.85
# 26515       NaN            0.0       0.000000    806.0   330.62   288.27
# 26516       NaN            0.0      14.333333   9993.0  1202.81  1076.56
# 26517       LDD            0.0       4.666667   8536.0  1071.28   959.03
#
#        avgrev  Customer_ID  comp_dat_Mean  plcd_dat_Mean
# 0       37.62      1064525       0.000000       0.000000
# 1       44.88      1048538       0.333333       0.333333
# 2       58.75      1010139       0.000000       0.333333
# 3       68.65      1014496       0.000000       0.000000
# 4       29.57      1012053       0.000000       0.000000
# ...       ...          ...            ...            ...
# 26513  182.54      1048705       0.000000       0.000000
# 26514   44.89      1026617       0.000000       0.000000
# 26515   32.03      1085271       0.000000       0.000000
# 26516   71.77      1050542       0.000000       0.000000
# 26517   79.92      1021809       0.000000       0.000000
#
# [26518 rows x 82 columns]

# %%
def miss_data(df):
    x = ['column_name','missing_data', 'missing_in_percentage']
    missing_data = pd.DataFrame(columns=x)
    columns = df.columns
    for col in columns:
        icolumn_name = col
        imissing_data = df[col].isnull().sum()
        imissing_in_percentage = (df[col].isnull().sum()/df[col].shape[0])*100

        missing_data.loc[len(missing_data)] = [icolumn_name, imissing_data, imissing_in_percentage]
    print(missing_data)

# %%
#Percentage_missing=  
missing_value_df.sort_values('Percent_missing', inplace=True)
#data.frame(MissingProportion=sort(Percentage_missing, decreasing = TRUE))

# %%
round(df.isnull().mean()*100,2)
# Out:
# Unnamed: 0       0.00
# mou_Mean         0.22
# totmrc_Mean      0.22
# rev_Range        0.22
# mou_Range        0.22
#                  ...
# adjrev           0.00
# avgrev           0.00
# Customer_ID      0.00
# comp_dat_Mean    0.00
# plcd_dat_Mean    0.00
# Length: 82, dtype: float64

# %%
miss_data.sort_values('Percent_missing', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-6db407f992cd> in <module>
# ----> 1 miss_data.sort_values('Percent_missing', inplace=True)
#
# AttributeError: 'function' object has no attribute 'sort_values'

# %%
print(missing_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-571750815315> in <module>
# ----> 1 print(missing_data)
#
# NameError: name 'missing_data' is not defined

# %%
import matplotlib.pyplot as plt
